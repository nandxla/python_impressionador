# %%
from pathlib import Path 
import shutil

# %%
# importamt methods
print(Path.cwd()) # local atual
# Out:
# C:\Users\nando\Documents\python_impressionador

# %%
files_path = Path.cwd() / 'Arquivos'
print(files_path.is_dir())
# Out:
# True

# %%
iterable_path = files_path.iterdir()
print(iterable_path)

for csv_file in iterable_path:
    print(csv_file)
# Out:
# <generator object Path.iterdir at 0x000002021B04D0B0>
# C:\Users\nando\Documents\python_impressionador\Arquivos\201801_Amazonas Shopping_AM.csv
# C:\Users\nando\Documents\python_impressionador\Arquivos\201801_Barra Shopping_RJ.csv
# C:\Users\nando\Documents\python_impressionador\Arquivos\201801_BH Shopping_MG.csv
# C:\Users\nando\Documents\python_impressionador\Arquivos\201801_Bourbon_SP.csv
# C:\Users\nando\Documents\python_impressionador\Arquivos\201801_Buriti Shopping_GO.csv
# C:\Users\nando\Documents\python_impressionador\Arquivos\201801_Cidade de Sao Paulo_SP.csv
# C:\Users\nando\Documents\python_impressionador\Arquivos\201801_Goiania Shopping_GO.csv
# C:\Users\nando\Documents\python_impressionador\Arquivos\201801_Ibirapuera_SP.csv
# C:\Users\nando\Documents\python_impressionador\Arquivos\201801_Iguatemi_SP.csv
# C:\Users\nando\Documents\python_impressionador\Arquivos\201801_Independência Shopping_MG.csv
# ...

# %%
# criando nova pasta
if not (Path.cwd() / '19_integracao_arquivos_pastas' / 'nova pasta').exists(): 
    (Path.cwd() / '19_integracao_arquivos_pastas' / 'nova pasta').mkdir()
    
(Path.cwd() / '19_integracao_arquivos_pastas' / 'outra pasta').mkdir()
