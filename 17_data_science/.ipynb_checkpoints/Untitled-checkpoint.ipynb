# %%
import pandas as pd

# %%
contoso_cadastro_produtos = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
contoso_clientes = pd.read_csv(r'Contoso - Clientes.csv', sep=';')
contoso_lojas = pd.read_csv(r'Contoso - Lojas.csv', sep=';')
contoso_promocoes = pd.read_csv(r'Contoso - Promocoes.csv', sep=';')
contoso_vendas_2017 = pd.read_csv(r'Contoso - Vendas - 2017.csv', sep=';')

# %%
# first step -> treat the data

display(contoso_vendas_2017)  # main dataframe 
display(contoso_cadastro_produtos)
display(contoso_clientes)
display(contoso_lojas)
display(contoso_promocoes)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
contoso_cadastro_produtos = contoso_cadastro_produtos[['Nome da Marca', 'ID Produto']]
contoso_clientes = contoso_clientes[['Primeiro Nome', 'E-mail', 'ID Cliente']]
contoso_lojas = contoso_lojas[['Nome da Loja', 'ID Loja']]
contoso_promocoes = contoso_promocoes[['Nome Promocao', 'ID Promocao']]

display(contoso_cadastro_produtos)
display(contoso_clientes)
display(contoso_lojas)
display(contoso_promocoes)
display(contoso_vendas_2017)
# Out:
#          Nome da Marca  ID Produto
# 0              Contoso         873
# 1              Contoso         879
# 2              Contoso         880
# 3              Contoso         881
# 4              Contoso         882
# ...                ...         ...
# 1685  Southridge Video        1602
# 1686  Southridge Video        1606
# 1687  Southridge Video        1607
# 1688  Southridge Video        1611
# 1689  Southridge Video        1612
#
# [1690 rows x 2 columns]
#       Primeiro Nome                         E-mail  ID Cliente
# 0            Garnet    glanfranchi0@mayoclinic.com           1
# 1           Lurette      lroseblade1@bigcartel.com           2
# 2           Glenden      gishchenko2@moonfruit.com           3
# 3             Baron    bjedrzejewsky3@e-recht24.de           4
# 4            Sheree       sbredbury4@sitemeter.com           5
# ...             ...                            ...         ...
# 39499        Brandy    brandy0@adventure-works.com       39500
# ...

# %%
contoso_vendas_2017 = contoso_vendas_2017.merge('contoso_cadastro_produtos', on='ID Produto')
contoso_vendas_2017 = contoso_vendas_2017.merge('contoso_clientes', on='ID Cliente')
contoso_vendas_2017 = contoso_vendas_2017.merge('contoso_lojas', on='ID Loja')
contoso_vendas_2017 = contoso_vendas_2017.merge('contoso_promocoes', on='ID Promocao')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 contoso_vendas_2017 = contoso_vendas_2017.merge('contoso_cadastro_produtos', on='ID Produto')
#       2 contoso_vendas_2017 = contoso_vendas_2017.merge('contoso_clientes', on='ID Cliente')
#       3 contoso_vendas_2017 = contoso_vendas_2017.merge('contoso_lojas', on='ID Loja')
#
# File ~\Anaconda3\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
# ...
